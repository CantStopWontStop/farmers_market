# %%
import pandas as pd
from config import username, password
import sqlalchemy as sa

# %%
#connected to base
engine = sa.create_engine(f'postgresql://({username}):{password}@localhost:5438/postgres')

# %%
#read farmers_markets csv 8804 rows × 59 columns
farmer_market = pd.read_csv('resources/farmers_markets_from_usda.csv')
farmer_market.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
#read svi_county .csv 3143 rows × 158 columns
svi_county = pd.read_csv('resources/SVI2020_US_COUNTY.csv')
svi_county
# Out:
#       ST    STATE ST_ABBR  STCNTY      COUNTY   FIPS  \
# 0      1  Alabama      AL    1001     Autauga   1001
# 1      1  Alabama      AL    1003     Baldwin   1003
# 2      1  Alabama      AL    1005     Barbour   1005
# 3      1  Alabama      AL    1007        Bibb   1007
# 4      1  Alabama      AL    1009      Blount   1009
# ...   ..      ...     ...     ...         ...    ...
# 3138  56  Wyoming      WY   56037  Sweetwater  56037
# 3139  56  Wyoming      WY   56039       Teton  56039
# 3140  56  Wyoming      WY   56041       Uinta  56041
# 3141  56  Wyoming      WY   56043    Washakie  56043
# 3142  56  Wyoming      WY   56045      Weston  56045
#
#                         LOCATION     AREA_SQMI  E_TOTPOP  M_TOTPOP  ...  \
# 0        Autauga County, Alabama    594.455838     55639         0  ...
# 1        Baldwin County, Alabama   1589.835294    218289         0  ...
# 2        Barbour County, Alabama    885.007618     25026         0  ...
# ...

# %%
# svi_county.set_index('FIPS',drop=True, inplace=True)
# svi_county
# Out:
#        ST    STATE ST_ABBR  STCNTY      COUNTY                    LOCATION  \
# FIPS
# 1001    1  Alabama      AL    1001     Autauga     Autauga County, Alabama
# 1003    1  Alabama      AL    1003     Baldwin     Baldwin County, Alabama
# 1005    1  Alabama      AL    1005     Barbour     Barbour County, Alabama
# 1007    1  Alabama      AL    1007        Bibb        Bibb County, Alabama
# 1009    1  Alabama      AL    1009      Blount      Blount County, Alabama
# ...    ..      ...     ...     ...         ...                         ...
# 56037  56  Wyoming      WY   56037  Sweetwater  Sweetwater County, Wyoming
# 56039  56  Wyoming      WY   56039       Teton       Teton County, Wyoming
# 56041  56  Wyoming      WY   56041       Uinta       Uinta County, Wyoming
# 56043  56  Wyoming      WY   56043    Washakie    Washakie County, Wyoming
# 56045  56  Wyoming      WY   56045      Weston      Weston County, Wyoming
#
# ...

# %%
#created svicounty_df  with selected column fields 3143 rows × 14 columns
svicounty_df = svi_county[['STATE','COUNTY','E_TOTPOP','E_POV150','M_POV150','E_UNEMP','M_UNEMP','E_HBURD','M_HBURD','E_NOHSDP','M_NOHSDP','E_UNINSUR','M_UNINSUR','E_MINRTY','M_MINRTY','EP_MINRTY','MP_MINRTY','EPL_MINRTY']]
svicounty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATE       3143 non-null   object
#  1   COUNTY      3143 non-null   object
#  2   E_TOTPOP    3143 non-null   int64
#  3   E_POV150    3143 non-null   int64
#  4   M_POV150    3143 non-null   int64
#  5   E_UNEMP     3143 non-null   int64
#  6   M_UNEMP     3143 non-null   int64
#  7   E_HBURD     3143 non-null   int64
#  8   M_HBURD     3143 non-null   int64
#  9   E_NOHSDP    3143 non-null   int64
#  10  M_NOHSDP    3143 non-null   int64
#  11  E_UNINSUR   3143 non-null   int64
#  12  M_UNINSUR   3143 non-null   int64
#  13  E_MINRTY    3143 non-null   int64
#  14  M_MINRTY    3143 non-null   int64
#  15  EP_MINRTY   3143 non-null   float64
#  16  MP_MINRTY   3143 non-null   float64
#  17  EPL_MINRTY  3143 non-null   float64
# dtypes: float64(3), int64(13), object(2)
# ...

# %%
#created farmer_market_df  with selected column fields 8804 rows × 10 columns
farmer_market_df = farmer_market[['FMID','MarketName','street','city','County','State','zip','x','y']]
farmer_market_df.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                    street      city     County           State    zip  \
# 0                     NaN  Danville  Caledonia         Vermont   5828
# 1         6975 Ridge Road    Parma    Cuyahoga            Ohio    NaN
# 2      106 S. Main Street  Six Mile    Pickens  South Carolina  29682
# 3  10th Street and Poplar    Lamar      Barton        Missouri  64759
# 4    112th Madison Avenue  New York   New York        New York  10029
#
#            x          y
# 0 -72.140335  44.411037
# 1 -81.733940  41.374802
# 2 -82.818703  34.804199
# 3 -94.274620  37.495628
# 4 -73.949303  40.793900

# %%
#remove any null values
clean_farm_market=farmer_market_df.dropna()
clean_farm_market
# Out:
#          FMID                                  MarketName  \
# 2     1009364           106 S. Main Street Farmers Market
# 3     1010691         10th Steet Community Farmers Market
# 4     1002454                        112st Madison Avenue
# 5     1011100                     12 South Farmers Market
# 6     1009845  125th Street Fresh Connect Farmers' Market
# ...       ...                                         ...
# 8797  1019792          Zelienople-Harmony Farmer's Market
# 8798  1007097            Zerns Farmers Market and Auction
# 8801  1012380                  Zion Canyon Farmers Market
# 8802  1004686                   Zionsville Farmers Market
# 8803  1011418                   Zona Rosa Farmers' Market
#
#                                                  street           city  \
# 2                                    106 S. Main Street       Six Mile
# 3                                10th Street and Poplar         Lamar
# ...

# %%
#remove any null values
clean_svicounty_df=svicounty_df.dropna()
clean_svicounty_df
# Out:
#         STATE      COUNTY  E_TOTPOP  E_POV150  M_POV150  E_UNEMP  M_UNEMP  \
# 0     Alabama     Autauga     55639     12611      1349      736      185
# 1     Alabama     Baldwin    218289     36413      2802     4027      714
# 2     Alabama     Barbour     25026      8965       673      649      182
# 3     Alabama        Bibb     22374      5730       907      667      260
# 4     Alabama      Blount     57755     13624      1151     1253      301
# ...       ...         ...       ...       ...       ...      ...      ...
# 3138  Wyoming  Sweetwater     43352      7713      1048     1437      348
# 3139  Wyoming       Teton     23356      2779       765      280      173
# 3140  Wyoming       Uinta     20374      3673       688      453      200
# 3141  Wyoming    Washakie      7933      1484       348      170       76
# 3142  Wyoming      Weston      6942      1316       356      118       77
#
#       E_HBURD  M_HBURD  E_NOHSDP  M_NOHSDP  E_UNINSUR  M_UNINSUR  E_MINRTY  \
# ...

# %%
clean_svicounty_df['county_lower']=clean_svicounty_df['COUNTY'].str.lower()
clean_farm_market['county_lower']=clean_farm_market['County'].str.lower()
# Out:
# C:\Users\parkm\AppData\Local\Temp\ipykernel_64540\3154024816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_farm_market['county_lower']=clean_farm_market['County'].str.lower()

# %%
#created clean_svicounty_dff and created merge
clean_svicounty_dff = pd.merge(clean_svicounty_df, clean_farm_market, how="outer", left_on=['county_lower','STATE'], right_on=['county_lower','State'])
clean_svicounty_dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8671 entries, 0 to 8670
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   STATE         8585 non-null   object
#  1   COUNTY        8585 non-null   object
#  2   E_TOTPOP      8585 non-null   float64
#  3   E_POV150      8585 non-null   float64
#  4   M_POV150      8585 non-null   float64
#  5   E_UNEMP       8585 non-null   float64
#  6   M_UNEMP       8585 non-null   float64
#  7   E_HBURD       8585 non-null   float64
#  8   M_HBURD       8585 non-null   float64
#  9   E_NOHSDP      8585 non-null   float64
#  10  M_NOHSDP      8585 non-null   float64
#  11  E_UNINSUR     8585 non-null   float64
#  12  M_UNINSUR     8585 non-null   float64
#  13  E_MINRTY      8585 non-null   float64
#  14  M_MINRTY      8585 non-null   float64
#  15  EP_MINRTY     8585 non-null   float64
#  16  MP_MINRTY     8585 non-null   float64
# ...

# %%
final_svicounty_dff = clean_svicounty_dff.drop(columns=['STATE','COUNTY','county_lower'])

# %%
final_svicounty_dff.to_csv('resources/farmers_market_svi.csv',index=False)

# %%
final_svicounty_dff=final_svicount_dff.astype({'E_TOTPOP':int,
                                               'E_POV150':int,
                                               'M_POV150':int,
                                               'E_UNEMP':int,
                                               'M_UNEMP':int,
                                               'E_HBURD':int,
                                               'M_HBURD':int,
                                               'E_NOHSDP':int,
                                               'M_NOHSDP':int,
                                               'E_UNINSUR':int,
                                               'M_UNINSUR':int,
                                               'E_MINRTY':int,
                                               'M_MINRTY':int,
                                               'EP_MINRTY':int,
                                               'MP_MINRTY':int})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 final_svicounty_dff=final_svicount_dff.astype({'E_TOTPOP':int,
#       2                                                'E_POV150':int,
#       3                                                'M_POV150':int,
#       4                                                'E_UNEMP':int,
#       5                                                'M_UNEMP':int,
#       6                                                'E_HBURD':int,
#       7                                                'M_HBURD':int,
#       8                                                'E_NOHSDP':int,
#       9                                                'M_NOHSDP':int,
#      10                                                'E_UNINSUR':int,
#      11                                                'M_UNINSUR':int,
# ...
