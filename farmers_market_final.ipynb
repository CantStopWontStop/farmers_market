# %%
# dependencies
import pandas as pd
from config import username, password
import sqlalchemy as sa

# %%
#connected to database
engine = sa.create_engine(f'postgresql://{username}:{password}@localhost:5432/farmers_market_db')

# %%
# import data from csvs
farmer_market = pd.read_csv('resources/farmers_markets_from_usda.csv')
svi_county = pd.read_csv('resources/SVI2020_US_COUNTY.csv')

# %%
# trim dataframes to selected columns of interest
svicounty_df = svi_county[['STATE','COUNTY','E_TOTPOP','E_POV150','M_POV150','E_UNEMP','M_UNEMP','E_HBURD','M_HBURD','E_NOHSDP','M_NOHSDP','E_UNINSUR','M_UNINSUR','E_MINRTY','M_MINRTY','EP_MINRTY','MP_MINRTY','EPL_MINRTY']]
farmer_market_df = farmer_market[['FMID','MarketName','street','city','County','State','zip','x','y']]

# %%
#remove any records with null values in county columns
clean_farm_market=farmer_market_df[farmer_market_df['County'].notna()]
clean_svicounty_df=svicounty_df[svicounty_df['COUNTY'].notna()]

# %%
# replace county name values to correct typos and errors
clean_farm_market.loc[(clean_farm_market['County'] == 'Deklab') & (clean_farm_market['State'] == 'Alabama'), 'County'] = 'Dekalb'
clean_farm_market.loc[(clean_farm_market['County'] == 'Valdex Cordova') & (clean_farm_market['State'] == 'Alaska'), 'County'] = 'Chugach'
clean_farm_market.loc[(clean_farm_market['County'] == 'Valdez-Cordova') & (clean_farm_market['State'] == 'Alaska'), 'County'] = 'Chugach'
clean_farm_market.loc[(clean_farm_market['County'] == 'Juneau') & (clean_farm_market['State'] == 'Alaska'), 'County'] = 'Juneau City and Borough'
clean_farm_market.loc[(clean_farm_market['County'] == 'Wrangell-Petersburg') & (clean_farm_market['State'] == 'Alaska'), 'County'] = 'Petersburg'
clean_farm_market.loc[(clean_farm_market['County'] == 'Sitka') & (clean_farm_market['State'] == 'Alaska'), 'County'] = 'Sitka City and Borough'
clean_farm_market.loc[(clean_farm_market['County'] == 'Shasta') & (clean_farm_market['State'] == 'Arkansas'), 'County'] = 'Benton'
clean_farm_market.loc[(clean_farm_market['County'] == 'St. Anislaus') & (clean_farm_market['State'] == 'California'), 'County'] = 'Stanislaus'
clean_farm_market.loc[(clean_farm_market['County'] == 'Coweta ') & (clean_farm_market['State'] == 'Georgia'), 'County'] = 'Coweta'
clean_farm_market.loc[(clean_farm_market['County'] == 'Dade') & (clean_farm_market['State'] == 'Florida'), 'County'] = 'Miami-Dade'
clean_farm_market.loc[(clean_farm_market['County'] == 'Anderson') & (clean_farm_market['State'] == 'Indiana'), 'County'] = 'Madison'
clean_farm_market.loc[(clean_farm_market['County'] == 'La Porte') & (clean_farm_market['State'] == 'Indiana'), 'County'] = 'LaPorte'
clean_farm_market.loc[(clean_farm_market['County'] == 'Placer') & (clean_farm_market['State'] == 'Indiana'), 'County'] = 'Dekalb'
clean_farm_market.loc[(clean_farm_market['County'] == 'La Salle') & ((clean_farm_market['State'] == 'Louisiana') | (clean_farm_market['State'] == 'Illinois')), 'County'] = 'LaSalle'
clean_farm_market.loc[(clean_farm_market['County'] == 'Anderoscoggin') & (clean_farm_market['State'] == 'Maine'), 'County'] = 'Androscoggin'
clean_farm_market.loc[(clean_farm_market['County'] == 'Burlington ') & (clean_farm_market['State'] == 'New Jersey'), 'County'] = 'Burlington'
clean_farm_market.loc[(clean_farm_market['County'] == 'Dona Ana') & (clean_farm_market['State'] == 'New Mexico'), 'County'] = 'Doña Ana'
clean_farm_market.loc[(clean_farm_market['County'] == 'Miama ') & (clean_farm_market['State'] == 'Ohio'), 'County'] = 'Miami'
clean_farm_market.loc[(clean_farm_market['County'] == 'Northhampton') & (clean_farm_market['State'] == 'Pennsylvania'), 'County'] = 'Northampton'
clean_farm_market.loc[(clean_farm_market['County'] == 'Shannon') & (clean_farm_market['State'] == 'South Dakota'), 'County'] = 'Oglala Lakota'
clean_farm_market.loc[(clean_farm_market['County'] == 'Carrollton') & (clean_farm_market['State'] == 'Texas'), 'County'] = 'Dallas'
clean_farm_market.loc[(clean_farm_market['County'] == 'EL Paso') & (clean_farm_market['State'] == 'Texas'), 'County'] = 'El Paso'
clean_farm_market.loc[(clean_farm_market['County'] == 'Harris ') & (clean_farm_market['State'] == 'Texas'), 'County'] = 'Harris'
clean_farm_market.loc[(clean_farm_market['County'] == 'Albemarle County') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Albemarle County'
clean_farm_market.loc[(clean_farm_market['County'] == 'Chesapeake') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Chesapeake City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Chesapeake City') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Chesapeake City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Chesterfield County') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Chesterfield'
clean_farm_market.loc[(clean_farm_market['County'] == 'Galax City') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Galax City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Galax') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Galax City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Hampton') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Hampton City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Falls Church') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Falls Church city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Charlottesville') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Charlottesville city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Norfolk') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Norfolk city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Lynchburg') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Lynchburg city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Norton') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Norton city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Virginia Beach') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Virginia Beach city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Portsmouth') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Portsmouth city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Radford') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Radford city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Petersburg') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Petersburg city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Monroe') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Albemarle County'
clean_farm_market.loc[(clean_farm_market['County'] == 'Suffolk') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Suffolk city'
clean_farm_market.loc[(clean_farm_market['County'] == 'Chesterfield') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Chesterfield'
clean_farm_market.loc[(clean_farm_market['County'] == 'Alexandria') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Alexandria City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Manassas') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Manassas City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Williamsburg') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Williamsburg City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Buena Vista') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Buena Vista City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Newport News') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Newport News City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Emporia') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Emporia'
clean_farm_market.loc[(clean_farm_market['County'] == 'Danville') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Danville City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Danville') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Danville City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Pima County') & (clean_farm_market['State'] == 'Arizona'), 'County'] = 'Pima'
clean_farm_market.loc[(clean_farm_market['County'] == 'Graham County') & (clean_farm_market['State'] == 'Arizona'), 'County'] = 'Graham'
clean_farm_market.loc[(clean_farm_market['County'] == 'Jackson County') & (clean_farm_market['State'] == 'Wisconsin'), 'County'] = 'Jackson'
clean_farm_market.loc[(clean_farm_market['County'] == 'Winnebago County') & (clean_farm_market['State'] == 'Wisconsin'), 'County'] = 'Winnebago'
clean_farm_market.loc[(clean_farm_market['County'] == 'Pepin County') & (clean_farm_market['State'] == 'Wisconsin'), 'County'] = 'Pepin'
clean_farm_market.loc[(clean_farm_market['County'] == 'Talladega County') & (clean_farm_market['State'] == 'Alabama'), 'County'] = 'Talladega'
clean_farm_market.loc[(clean_farm_market['County'] == 'Lawrence County') & (clean_farm_market['State'] == 'Arkansas'), 'County'] = 'Lawrence'
clean_farm_market.loc[(clean_farm_market['County'] == 'Mississippi County') & (clean_farm_market['State'] == 'Arkansas'), 'County'] = 'Mississippi'
clean_farm_market.loc[(clean_farm_market['County'] == 'Sebastian County') & (clean_farm_market['State'] == 'Arkansas'), 'County'] = 'Sebastian'
clean_farm_market.loc[(clean_farm_market['County'] == 'Phillips County') & (clean_farm_market['State'] == 'Arkansas'), 'County'] = 'Phillips'
clean_farm_market.loc[(clean_farm_market['County'] == 'Riverside County') & (clean_farm_market['State'] == 'California'), 'County'] = 'Riverside'
clean_farm_market.loc[(clean_farm_market['County'] == 'San Mateo County') & (clean_farm_market['State'] == 'California'), 'County'] = 'San Mateo'
clean_farm_market.loc[(clean_farm_market['County'] == 'Butte County') & (clean_farm_market['State'] == 'California'), 'County'] = 'Butte'
clean_farm_market.loc[(clean_farm_market['County'] == 'Jefferson County') & (clean_farm_market['State'] == 'Colorado'), 'County'] = 'Jefferson'
clean_farm_market.loc[(clean_farm_market['County'] == 'Windham County') & (clean_farm_market['State'] == 'Connecticut'), 'County'] = 'Windham'
clean_farm_market.loc[(clean_farm_market['County'] == 'Indian River County') & (clean_farm_market['State'] == 'Florida'), 'County'] = 'Indian River'
clean_farm_market.loc[(clean_farm_market['County'] == 'Marion County') & (clean_farm_market['State'] == 'Florida'), 'County'] = 'Marion'
clean_farm_market.loc[(clean_farm_market['County'] == 'Escambia County') & (clean_farm_market['State'] == 'Florida'), 'County'] = 'Escambia'
clean_farm_market.loc[(clean_farm_market['County'] == 'Laurens County') & (clean_farm_market['State'] == 'Georgia'), 'County'] = 'Laurens'
clean_farm_market.loc[(clean_farm_market['County'] == 'Hawaii County') & (clean_farm_market['State'] == 'Hawaii'), 'County'] = 'Hawaii'
clean_farm_market.loc[(clean_farm_market['County'] == 'Parke County') & (clean_farm_market['State'] == 'Indiana'), 'County'] = 'Parke'
clean_farm_market.loc[(clean_farm_market['County'] == 'Lyon County') & (clean_farm_market['State'] == 'Iowa'), 'County'] = 'Lyon'
clean_farm_market.loc[(clean_farm_market['County'] == 'Woodbury County') & (clean_farm_market['State'] == 'Iowa'), 'County'] = 'Woodbury'
clean_farm_market.loc[(clean_farm_market['County'] == 'Butler County') & (clean_farm_market['State'] == 'Kansas'), 'County'] = 'Butler'
clean_farm_market.loc[(clean_farm_market['County'] == 'Osage County') & (clean_farm_market['State'] == 'Kansas'), 'County'] = 'Osage'
clean_farm_market.loc[(clean_farm_market['County'] == 'Coffey County') & (clean_farm_market['State'] == 'Kansas'), 'County'] = 'Coffey'
clean_farm_market.loc[(clean_farm_market['County'] == 'Adair County') & (clean_farm_market['State'] == 'Kentucky'), 'County'] = 'Adair'
clean_farm_market.loc[(clean_farm_market['County'] == 'Madison Parish') & (clean_farm_market['State'] == 'Louisiana'), 'County'] = 'Madison'
clean_farm_market.loc[(clean_farm_market['County'] == 'Sabine Parish') & (clean_farm_market['State'] == 'Louisiana'), 'County'] = 'Sabine'
clean_farm_market.loc[(clean_farm_market['County'] == 'Somerset County') & (clean_farm_market['State'] == 'Maryland'), 'County'] = 'Somerset'
clean_farm_market.loc[(clean_farm_market['County'] == "Prince George's County") & (clean_farm_market['State'] == 'Maryland'), 'County'] = "Prince George's"
clean_farm_market.loc[(clean_farm_market['County'] == 'Dukes County') & (clean_farm_market['State'] == 'Massachusetts'), 'County'] = 'Dukes'
clean_farm_market.loc[(clean_farm_market['County'] == 'Barnstable ') & (clean_farm_market['State'] == 'Massachusetts'), 'County'] = 'Barnstable'
clean_farm_market.loc[(clean_farm_market['County'] == 'Lapeer County') & (clean_farm_market['State'] == 'Michigan'), 'County'] = 'Lapeer'
clean_farm_market.loc[(clean_farm_market['County'] == 'Jackson County') & (clean_farm_market['State'] == 'Michigan'), 'County'] = 'Jackson'
clean_farm_market.loc[(clean_farm_market['County'] == 'Kent County') & (clean_farm_market['State'] == 'Michigan'), 'County'] = 'Kent'
clean_farm_market.loc[(clean_farm_market['County'] == 'Ogemaw County') & (clean_farm_market['State'] == 'Michigan'), 'County'] = 'Ogemaw'
clean_farm_market.loc[(clean_farm_market['County'] == 'Kandiyohi County') & (clean_farm_market['State'] == 'Minnesota'), 'County'] = 'Kandiyohi'
clean_farm_market.loc[(clean_farm_market['County'] == 'Dakota County') & (clean_farm_market['State'] == 'Minnesota'), 'County'] = 'Dakota'
clean_farm_market.loc[(clean_farm_market['County'] == 'Cass County') & (clean_farm_market['State'] == 'Minnesota'), 'County'] = 'Cass'
clean_farm_market.loc[(clean_farm_market['County'] == 'Clay County') & (clean_farm_market['State'] == 'Minnesota'), 'County'] = 'Clay'
clean_farm_market.loc[(clean_farm_market['County'] == 'Hennepin County') & (clean_farm_market['State'] == 'Minnesota'), 'County'] = 'Hennepin'
clean_farm_market.loc[(clean_farm_market['County'] == 'Stone County') & (clean_farm_market['State'] == 'Mississippi'), 'County'] = 'Stone'
clean_farm_market.loc[(clean_farm_market['County'] == 'Coahoma County') & (clean_farm_market['State'] == 'Mississippi'), 'County'] = 'Coahoma'
clean_farm_market.loc[(clean_farm_market['County'] == 'Garfield County') & (clean_farm_market['State'] == 'Nebraska'), 'County'] = 'Garfield'
clean_farm_market.loc[(clean_farm_market['County'] == 'Middlesex County') & (clean_farm_market['State'] == 'New Jersey'), 'County'] = 'Middlesex'
clean_farm_market.loc[(clean_farm_market['County'] == 'Morris County') & (clean_farm_market['State'] == 'New Jersey'), 'County'] = 'Morris'
clean_farm_market.loc[(clean_farm_market['County'] == 'Mercer County') & (clean_farm_market['State'] == 'New Jersey'), 'County'] = 'Mercer'
clean_farm_market.loc[(clean_farm_market['County'] == 'Schuyler County') & (clean_farm_market['State'] == 'New York'), 'County'] = 'Schuyler'
clean_farm_market.loc[(clean_farm_market['County'] == 'Albany County') & (clean_farm_market['State'] == 'New York'), 'County'] = 'Albany'
clean_farm_market.loc[(clean_farm_market['County'] == 'Avery County') & (clean_farm_market['State'] == 'North Carolina'), 'County'] = 'Avery'
clean_farm_market.loc[(clean_farm_market['County'] == 'Moore County') & (clean_farm_market['State'] == 'North Carolina'), 'County'] = 'Moore'
clean_farm_market.loc[(clean_farm_market['County'] == 'Harnett County') & (clean_farm_market['State'] == 'North Carolina'), 'County'] = 'Harnett'
clean_farm_market.loc[(clean_farm_market['County'] == 'Watauga County') & (clean_farm_market['State'] == 'North Carolina'), 'County'] = 'Watauga'
clean_farm_market.loc[(clean_farm_market['County'] == 'Orange County') & (clean_farm_market['State'] == 'North Carolina'), 'County'] = 'Orange'
clean_farm_market.loc[(clean_farm_market['County'] == 'Jackson County') & (clean_farm_market['State'] == 'North Carolina'), 'County'] = 'Jackson'
clean_farm_market.loc[(clean_farm_market['County'] == 'Tyrrell County') & (clean_farm_market['State'] == 'North Carolina'), 'County'] = 'Tyrrell'
clean_farm_market.loc[(clean_farm_market['County'] == 'McIntosh County') & (clean_farm_market['State'] == 'North Dakota'), 'County'] = 'McIntosh'
clean_farm_market.loc[(clean_farm_market['County'] == 'Greene County') & (clean_farm_market['State'] == 'Ohio'), 'County'] = 'Greene'
clean_farm_market.loc[(clean_farm_market['County'] == 'Hancock County') & (clean_farm_market['State'] == 'Ohio'), 'County'] = 'Hancock'
clean_farm_market.loc[(clean_farm_market['County'] == 'Van Wert County') & (clean_farm_market['State'] == 'Ohio'), 'County'] = 'Van Wert'
clean_farm_market.loc[(clean_farm_market['County'] == 'Holmes County') & (clean_farm_market['State'] == 'Ohio'), 'County'] = 'Holmes'
clean_farm_market.loc[(clean_farm_market['County'] == 'Guernsey County') & (clean_farm_market['State'] == 'Ohio'), 'County'] = 'Guernsey'
clean_farm_market.loc[(clean_farm_market['County'] == 'Tulsa County') & (clean_farm_market['State'] == 'Oklahoma'), 'County'] = 'Tulsa'
clean_farm_market.loc[(clean_farm_market['County'] == 'Oklahoma County') & (clean_farm_market['State'] == 'Oklahoma'), 'County'] = 'Oklahoma'
clean_farm_market.loc[(clean_farm_market['County'] == 'Grant County') & (clean_farm_market['State'] == 'Oklahoma'), 'County'] = 'Grant'
clean_farm_market.loc[(clean_farm_market['County'] == 'Malheur County') & (clean_farm_market['State'] == 'Oregon'), 'County'] = 'Malheur'
clean_farm_market.loc[(clean_farm_market['County'] == 'Umatilla County') & (clean_farm_market['State'] == 'Oregon'), 'County'] = 'Umatilla'
clean_farm_market.loc[(clean_farm_market['County'] == 'Douglas County') & (clean_farm_market['State'] == 'Oregon'), 'County'] = 'Douglas'
clean_farm_market.loc[(clean_farm_market['County'] == 'Centre County') & (clean_farm_market['State'] == 'Pennsylvania'), 'County'] = 'Centre'
clean_farm_market.loc[(clean_farm_market['County'] == 'Montgomery County') & (clean_farm_market['State'] == 'Pennsylvania'), 'County'] = 'Montgomery'
clean_farm_market.loc[(clean_farm_market['County'] == 'Jerauld County') & (clean_farm_market['State'] == 'South Dakota'), 'County'] = 'Jerauld'
clean_farm_market.loc[(clean_farm_market['County'] == 'Pennington County') & (clean_farm_market['State'] == 'South Dakota'), 'County'] = 'Pennington'
clean_farm_market.loc[(clean_farm_market['County'] == 'Fall River County') & (clean_farm_market['State'] == 'South Dakota'), 'County'] = 'Fall River'
clean_farm_market.loc[(clean_farm_market['County'] == 'Henderson County') & (clean_farm_market['State'] == 'Tennessee'), 'County'] = 'Henderson'
clean_farm_market.loc[(clean_farm_market['County'] == 'Rutherford County') & (clean_farm_market['State'] == 'Tennessee'), 'County'] = 'Rutherford'
clean_farm_market.loc[(clean_farm_market['County'] == 'Bexar County') & (clean_farm_market['State'] == 'Texas'), 'County'] = 'Bexar'
clean_farm_market.loc[(clean_farm_market['County'] == 'Fort Bend County') & (clean_farm_market['State'] == 'Texas'), 'County'] = 'Fort Bend'
clean_farm_market.loc[(clean_farm_market['County'] == 'Moore County') & (clean_farm_market['State'] == 'Texas'), 'County'] = 'Moore'
clean_farm_market.loc[(clean_farm_market['County'] == 'Sanpete County') & (clean_farm_market['State'] == 'Utah'), 'County'] = 'Sanpete'
clean_farm_market.loc[(clean_farm_market['County'] == 'Fort Bend County') & (clean_farm_market['State'] == 'Texas'), 'County'] = 'Fort Bend'
clean_farm_market.loc[(clean_farm_market['County'] == 'Fauquier County') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Fauquier'
clean_farm_market.loc[(clean_farm_market['County'] == 'Emporia') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Emporia City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Colonial Heights') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Colonial Heights City'
clean_farm_market.loc[(clean_farm_market['County'] == 'Albemarle County') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Albemarle'
clean_farm_market.loc[(clean_farm_market['County'] == 'Chesterfied') & (clean_farm_market['State'] == 'Virginia'), 'County'] = 'Chesterfield'
clean_farm_market.loc[(clean_farm_market['County'] == 'Whatcom County') & (clean_farm_market['State'] == 'Washington'), 'County'] = 'Whatcom'
clean_farm_market.loc[(clean_farm_market['County'] == 'Thurston ') & (clean_farm_market['State'] == 'Washington'), 'County'] = 'Thurston'
clean_farm_market.loc[(clean_farm_market['County'] == 'Pleasants County') & (clean_farm_market['State'] == 'West Virginia'), 'County'] = 'Pleasants'
clean_farm_market.loc[(clean_farm_market['County'] == 'Braxton County') & (clean_farm_market['State'] == 'West Virginia'), 'County'] = 'Braxton'
clean_farm_market.loc[(clean_farm_market['County'] == 'Vilas County') & (clean_farm_market['State'] == 'Wisconsin'), 'County'] = 'Vilas'
clean_farm_market.loc[(clean_farm_market['County'] == 'Goshen ') & (clean_farm_market['State'] == 'Wyoming'), 'County'] = 'Goshen'

# %%
# transform county names to lowercase for merging
clean_svicounty_df['county_lower']=clean_svicounty_df['COUNTY'].str.lower()
clean_farm_market['county_lower']=clean_farm_market['County'].str.lower()
# Out:
# C:\Users\parkm\AppData\Local\Temp\ipykernel_67532\1522928147.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_farm_market['county_lower']=clean_farm_market['County'].str.lower()

# %%
#created clean_svicounty_dff and created merge
clean_svicounty_dff = pd.merge(clean_farm_market, clean_svicounty_df, how="outer", right_on=['county_lower','STATE'], left_on=['county_lower','State'])
clean_svicounty_dff.head()
# Out:
#         FMID                                        MarketName  \
# 0  1018261.0   Caledonia Farmers Market Association - Danville
# 1  1018262.0   Caledonia Farmers Market Association - Saturday
# 2  1018263.0     Caledonia Farmers Market Association - Winter
# 3  1008831.0                    Groton Growers Farmers' Market
# 4  1006630.0                          Hardwick Farmers' Market
#
#                street            city     County    State   zip          x  \
# 0                 NaN        Danville  Caledonia  Vermont  5828 -72.140335
# 1            Pearl St  St. Johnsbury   Caledonia  Vermont  5819 -72.016640
# 2        Depot Square   St. Johnsbury  Caledonia  Vermont  5819 -72.015396
# 3  1476 Scott Highway          Groton  Caledonia  Vermont   NaN -72.197395
# 4         Granite St.        Hardwick  Caledonia  Vermont  5843 -72.371513
#
#            y county_lower  ... M_HBURD E_NOHSDP  M_NOHSDP  E_UNINSUR  \
# ...

# %%
# rename columns
clean_svicounty_dff = clean_svicounty_dff.rename(columns={
    'street':'street_farm',
    'city':'city_farm',
    'County':'county_farm',
    'State':'state_farm',
    'zip':'zip_farm',
    'x':'x_farm',
    'y':'y_farm',
    'COUNTY':'county_svi',
    'STATE':'state_svi'
})

# %%
# drop column for merging
final_svicounty_dff = clean_svicounty_dff.drop(columns=['county_lower'])

# drop data for territories - not available in SVI dataset
final_svicounty_dff = final_svicounty_dff[final_svicounty_dff.state_farm != 'Puerto Rico'] ## add this line to this cell since svi data are not available for PR
final_svicounty_dff = final_svicounty_dff[final_svicounty_dff.state_farm != 'Virgin Islands'] ## add this line to this cell since svi data are not available for PR

# preview data
final_svicounty_dff.head()
# Out:
#         FMID                                        MarketName  \
# 0  1018261.0   Caledonia Farmers Market Association - Danville
# 1  1018262.0   Caledonia Farmers Market Association - Saturday
# 2  1018263.0     Caledonia Farmers Market Association - Winter
# 3  1008831.0                    Groton Growers Farmers' Market
# 4  1006630.0                          Hardwick Farmers' Market
#
#           street_farm       city_farm county_farm state_farm zip_farm  \
# 0                 NaN        Danville   Caledonia    Vermont     5828
# 1            Pearl St  St. Johnsbury    Caledonia    Vermont     5819
# 2        Depot Square   St. Johnsbury   Caledonia    Vermont     5819
# 3  1476 Scott Highway          Groton   Caledonia    Vermont      NaN
# 4         Granite St.        Hardwick   Caledonia    Vermont     5843
#
#       x_farm     y_farm state_svi  ... M_HBURD  E_NOHSDP  M_NOHSDP  E_UNINSUR  \
# 0 -72.140335  44.411037   Vermont  ...   326.0    1548.0     216.0     1270.0
# ...

# %%
# save to database
final_svicounty_dff.to_sql(name='farmers_market_svi',con=engine,if_exists='append')

# save to csv
final_svicounty_dff.to_csv('resources/farmers_market_svi.csv')
# Out:
# 582
